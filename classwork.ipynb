# %%
6/4
# Out:
# 1.5

# %%
1 ** 3
# Out:
# 1

# %%
5 % 3
# Out:
# 2

# %%
1 % 3
# Out:
# 1

# %%
3.14
# Out:
# 3.14

# %%
interest = 0.03
principal = 3000
n = 1
final = (principal * (1 + interest / 100) ** n)
print(final)
# Out:
# 3000.9

# %%
print(1,3)
"1" + "3" + "/n"
# Out:
# 1 3
# '13/n'

# %%
print (interest, principal)
print (n)
# Out:
# 0.03 3000
# 1

# %%
print ('Interest rate', interest, sep='=>')
print ('Number of years', n)
# Out:
# Interest rate=>0.03
# Number of years 1

# %%
print ('Interest rate', interest, end='=>')
print('Number of years', n)
# Out:
# Interest rate 0.03=>Number of years 1

# %%
print('Interest rate', interest, sep='>>>', end='&&&')
print('Number of years', n, sep='')
# Out:
# Interest rate>>>0.03&&&Number of years1

# %%
print('Interest rate:', interest, ': Number of years= :', n)
# Out:
# Interest rate: 0.03 : Number of years= : 1

# %%
print('Interest rate: {}. Number of years={}'.format(interest, n))
print(f'Interest rate: {interest}. Number of years={n}')
# Out:
# Interest rate: 0.03. Number of years=1
# Interest rate: 0.03. Number of years=1

# %%
F"Interest Rate: {interest}. Number of years={n}"
# Out:
# 'Interest Rate: 0.03. Number of years=1'

# %%
print('Interest Rate:', interest)
# Out:
# Interest Rate: 0.03

# %%
interest = float(input('Enter interest value (%):'))
principal = float(input('Enter initial amount: ($):'))
m = int(input('Enter number of years:'))
final = principal * (1 + interest / 100) ** m
print('Total amount after', m, 'years is: $', final)
# Out:
# Total amount after 3 years is: $ 137.18812499999999
